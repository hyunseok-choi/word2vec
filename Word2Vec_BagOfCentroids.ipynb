# %%
# Load a pre-trained model
from gensim.models import Word2Vec
from sklearn.cluster import KMeans
import time
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords
import numpy as np
from KaggleWord2VecUtility import KaggleWord2VecUtility
# Out:
# C:\Dev\Anaconda3\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# Define a function to create bags of centroids
#
def create_bag_of_centroids(wordlist, word_centroid_map):
    #
    # The number of cluster is equal to the highest cluster index
    # in the word / centroid map
    num_centroids = max(word_centroid_map.values()) + 1
    #
    # Pre-allocate the bag of centroids vector (for speed)
    bag_of_centroids = np.zeros(num_centroids, dtype='float32')
    #
    # Loop over the words in the review. If the word is in the vocabulary,
    # find which cluster it belongs to, and increment that cluster count
    # by one
    for word in wordlist:
        if word in word_centroid_map:
            index = word_centroid_map[word]
            bag_of_centroids[index] += 1
    #
    # Return the 'bag of centroids'
    return bag_of_centroids

# %%
# Load the model that I created in 'Word2Vec_AverageVectors.ipynb'
model = Word2Vec.load('./300features_40minwords_10context')

# ****** Run k-means on the word vectors and print a few clusters
#

start = time.time() # Start time

# Set "k" (num_cluster) to be 1/5th of the vocabulary size, or an
# average of 5 words per cluster
word_vectors = model.wv.syn0
# syn0: the Word2Vec model loaded above, consists of a feature vector for
#       each word in the vocabulary
# word_vectors row: the number of words in the model's vocabulary
# word_vectors column: the size of the feature vector
print(model.wv.syn0.shape)
num_clusters = int(word_vectors.shape[0] / 5) 
# Initialize a k-means object and use it to extract centroids
print("Running K means with k = ", num_clusters)
kmeans_clustering = KMeans(n_clusters = num_clusters)
idx = kmeans_clustering.fit_predict(word_vectors)

# Get the end time and print how long the process took
end = time.time()
elapsed = end - start
print("Time taken for K Means clustering: ", elapsed, "seconds.")
# Out:
# (16490, 300)
# Running K means with k =  3298
# Time taken for K Means clustering:  929.8754115104675 seconds.

# %%
print(len(model.wv.vocab)) # the number of words in the model's vocabulary
model.wv.vocab # example of the vocabulary words
# Out:
# 16490
# {'yul': <gensim.models.keyedvectors.Vocab at 0x22dbea71240>,
#  'kinski': <gensim.models.keyedvectors.Vocab at 0x22dbeaf6518>,
#  'cheerfully': <gensim.models.keyedvectors.Vocab at 0x22dbea51a58>,
#  'opus': <gensim.models.keyedvectors.Vocab at 0x22dbed53e48>,
#  'jane': <gensim.models.keyedvectors.Vocab at 0x22dbea7f6d8>,
#  'imposing': <gensim.models.keyedvectors.Vocab at 0x22dbea47860>,
#  'downer': <gensim.models.keyedvectors.Vocab at 0x22dbed8ee48>,
#  'knightley': <gensim.models.keyedvectors.Vocab at 0x22dbed97710>,
#  'lengthy': <gensim.models.keyedvectors.Vocab at 0x22dbea75cc0>,
#  'wit': <gensim.models.keyedvectors.Vocab at 0x22dbec249b0>,
#  'jerky': <gensim.models.keyedvectors.Vocab at 0x22dbeb88f60>,
#  'customs': <gensim.models.keyedvectors.Vocab at 0x22dbec32400>,
#  'convinced': <gensim.models.keyedvectors.Vocab at 0x22dbeaffc50>,
#  'exiled': <gensim.models.keyedvectors.Vocab at 0x22dbea51c50>,
#  'dribble': <gensim.models.keyedvectors.Vocab at 0x22dbeae8470>,
#  'debra': <gensim.models.keyedvectors.Vocab at 0x22dbed1c8d0>,
#  'fondness': <gensim.models.keyedvectors.Vocab at 0x22dbeb12198>,
#  'communication': <gensim.models.keyedvectors.Vocab at 0x22dbea950b8>,
#  'annoy': <gensim.models.keyedvectors.Vocab at 0x22dbecd3b70>,
#  'aunt': <gensim.models.keyedvectors.Vocab at 0x22dbec770f0>,
#  'marjorie': <gensim.models.keyedvectors.Vocab at 0x22dbea55320>,
#  'ketchup': <gensim.models.keyedvectors.Vocab at 0x22dbeca9a20>,
#  'lawyer': <gensim.models.keyedvectors.Vocab at 0x22dbecdb550>,
#  'florence': <gensim.models.keyedvectors.Vocab at 0x22dbed01f60>,
#  'bolt': <gensim.models.keyedvectors.Vocab at 0x22dbea43780>,
#  'grader': <gensim.models.keyedvectors.Vocab at 0x22dbeca9f28>,
#  'evaluation': <gensim.models.keyedvectors.Vocab at 0x22dbec72e10>,
#  'reviewers': <gensim.models.keyedvectors.Vocab at 0x22dbeb7a5c0>,
#  'janice': <gensim.models.keyedvectors.Vocab at 0x22dbeaffa90>,
#  'loser': <gensim.models.keyedvectors.Vocab at 0x22dbea23978>,
#  'artsy': <gensim.models.keyedvectors.Vocab at 0x22dbeb36898>,
#  'rightly': <gensim.models.keyedvectors.Vocab at 0x22dbed052e8>,
#  'possibility': <gensim.models.keyedvectors.Vocab at 0x22dbfdb1b70>,
#  'yea': <gensim.models.keyedvectors.Vocab at 0x22dbec29588>,
#  'sweaty': <gensim.models.keyedvectors.Vocab at 0x22dbec32fd0>,
#  'whim': <gensim.models.keyedvectors.Vocab at 0x22dbed618d0>,
#  'necessary': <gensim.models.keyedvectors.Vocab at 0x22dbd71ba90>,
#  'chun': <gensim.models.keyedvectors.Vocab at 0x22dbec64400>,
#  'indians': <gensim.models.keyedvectors.Vocab at 0x22dbeadfba8>,
#  'decides': <gensim.models.keyedvectors.Vocab at 0x22dbeb760b8>,
#  'lee': <gensim.models.keyedvectors.Vocab at 0x22dbd705550>,
#  'circles': <gensim.models.keyedvectors.Vocab at 0x22dbea5f668>,
#  'demographic': <gensim.models.keyedvectors.Vocab at 0x22dbeccd5f8>,
#  'cillian': <gensim.models.keyedvectors.Vocab at 0x22dbed93320>,
#  'soundtracks': <gensim.models.keyedvectors.Vocab at 0x22dbec9b5f8>,
#  'melanie': <gensim.models.keyedvectors.Vocab at 0x22dbeb0cfd0>,
#  'extent': <gensim.models.keyedvectors.Vocab at 0x22dbec4d630>,
#  'pump': <gensim.models.keyedvectors.Vocab at 0x22dbfd71588>,
#  'homes': <gensim.models.keyedvectors.Vocab at 0x22dbea7fd68>,
#  'suggestion': <gensim.models.keyedvectors.Vocab at 0x22dbeb5abe0>,
#  'mccarthy': <gensim.models.keyedvectors.Vocab at 0x22dbebc4a90>,
#  'barton': <gensim.models.keyedvectors.Vocab at 0x22dbed33668>,
#  'dickens': <gensim.models.keyedvectors.Vocab at 0x22dbed33278>,
#  'simplest': <gensim.models.keyedvectors.Vocab at 0x22dbed9c6a0>,
#  'iron': <gensim.models.keyedvectors.Vocab at 0x22dbeb32fd0>,
#  'koch': <gensim.models.keyedvectors.Vocab at 0x22dbeaa32b0>,
#  'amicus': <gensim.models.keyedvectors.Vocab at 0x22dbecc0ac8>,
#  'liar': <gensim.models.keyedvectors.Vocab at 0x22dbeada668>,
#  'nosed': <gensim.models.keyedvectors.Vocab at 0x22dbed7cb70>,
#  'hilton': <gensim.models.keyedvectors.Vocab at 0x22dbea9a0f0>,
#  'god': <gensim.models.keyedvectors.Vocab at 0x22dbeb96240>,
#  'uncanny': <gensim.models.keyedvectors.Vocab at 0x22dbed37128>,
#  'pairing': <gensim.models.keyedvectors.Vocab at 0x22dbeb48c50>,
#  'lucio': <gensim.models.keyedvectors.Vocab at 0x22dbfdbeef0>,
#  'astonishing': <gensim.models.keyedvectors.Vocab at 0x22dbed25fd0>,
#  'russian': <gensim.models.keyedvectors.Vocab at 0x22dbeb68438>,
#  'laughable': <gensim.models.keyedvectors.Vocab at 0x22dbeb5a2b0>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x22dbed1cc18>,
#  'addition': <gensim.models.keyedvectors.Vocab at 0x22dbea75940>,
#  'hardcore': <gensim.models.keyedvectors.Vocab at 0x22dbeb92f98>,
#  'marriage': <gensim.models.keyedvectors.Vocab at 0x22dbfda8860>,
#  'typing': <gensim.models.keyedvectors.Vocab at 0x22dbebc05c0>,
#  'melting': <gensim.models.keyedvectors.Vocab at 0x22dbed37c18>,
#  'washing': <gensim.models.keyedvectors.Vocab at 0x22dbfd9a6a0>,
#  'disease': <gensim.models.keyedvectors.Vocab at 0x22dbed77710>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x22dbecf7c18>,
#  'edison': <gensim.models.keyedvectors.Vocab at 0x22dbd713780>,
#  'exiting': <gensim.models.keyedvectors.Vocab at 0x22dbeab5ac8>,
#  'unwatchable': <gensim.models.keyedvectors.Vocab at 0x22dbea75e80>,
#  'bothered': <gensim.models.keyedvectors.Vocab at 0x22dbec12630>,
#  'rounds': <gensim.models.keyedvectors.Vocab at 0x22dbea3e898>,
#  'randomness': <gensim.models.keyedvectors.Vocab at 0x22dbebba048>,
#  'sheridan': <gensim.models.keyedvectors.Vocab at 0x22dbecadb70>,
#  'hinting': <gensim.models.keyedvectors.Vocab at 0x22dbed8e2b0>,
#  'ardent': <gensim.models.keyedvectors.Vocab at 0x22dbed8e630>,
#  'feed': <gensim.models.keyedvectors.Vocab at 0x22dbec4df60>,
#  'shambles': <gensim.models.keyedvectors.Vocab at 0x22dbec5b438>,
#  'bootleg': <gensim.models.keyedvectors.Vocab at 0x22dbeb04828>,
#  'balances': <gensim.models.keyedvectors.Vocab at 0x22dbed93f60>,
#  'lom': <gensim.models.keyedvectors.Vocab at 0x22dbea916d8>,
#  'tennis': <gensim.models.keyedvectors.Vocab at 0x22dbfdcd828>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x22dbeb32518>,
#  'welch': <gensim.models.keyedvectors.Vocab at 0x22dbecf3240>,
#  'indies': <gensim.models.keyedvectors.Vocab at 0x22dbea43f60>,
#  'avenue': <gensim.models.keyedvectors.Vocab at 0x22dbec243c8>,
#  'jon': <gensim.models.keyedvectors.Vocab at 0x22dbd70e860>,
#  'fantastically': <gensim.models.keyedvectors.Vocab at 0x22dbed49630>,
#  'tailored': <gensim.models.keyedvectors.Vocab at 0x22dbed6e940>,
#  'admirer': <gensim.models.keyedvectors.Vocab at 0x22dbec80588>,
#  'bitch': <gensim.models.keyedvectors.Vocab at 0x22dbed93d30>,
#  'caliber': <gensim.models.keyedvectors.Vocab at 0x22dbeb28390>,
#  'increasingly': <gensim.models.keyedvectors.Vocab at 0x22dbfda8b38>,
#  'mercy': <gensim.models.keyedvectors.Vocab at 0x22dbed69c18>,
#  'metropolitan': <gensim.models.keyedvectors.Vocab at 0x22dbec8d358>,
#  'assortment': <gensim.models.keyedvectors.Vocab at 0x22dbfd75748>,
#  'depp': <gensim.models.keyedvectors.Vocab at 0x22dbd709d30>,
#  'popularity': <gensim.models.keyedvectors.Vocab at 0x22dbeabaa90>,
#  'surround': <gensim.models.keyedvectors.Vocab at 0x22dbea9f6a0>,
#  'rapidly': <gensim.models.keyedvectors.Vocab at 0x22dbed21198>,
#  'kristel': <gensim.models.keyedvectors.Vocab at 0x22dbed8e940>,
#  'ahh': <gensim.models.keyedvectors.Vocab at 0x22dbebc4978>,
#  'wolverine': <gensim.models.keyedvectors.Vocab at 0x22dbec00780>,
#  'dee': <gensim.models.keyedvectors.Vocab at 0x22dbed17240>,
#  'examines': <gensim.models.keyedvectors.Vocab at 0x22dbeba44a8>,
#  'fifteen': <gensim.models.keyedvectors.Vocab at 0x22dbed4ea58>,
#  'unseen': <gensim.models.keyedvectors.Vocab at 0x22dbea39978>,
#  'swift': <gensim.models.keyedvectors.Vocab at 0x22dbec16128>,
#  'duris': <gensim.models.keyedvectors.Vocab at 0x22dbfd8c5f8>,
#  'selfish': <gensim.models.keyedvectors.Vocab at 0x22dbeb2c588>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x22dbecdb630>,
#  'reunite': <gensim.models.keyedvectors.Vocab at 0x22dbeadfa58>,
#  'mistreated': <gensim.models.keyedvectors.Vocab at 0x22dbead65c0>,
#  'twelve': <gensim.models.keyedvectors.Vocab at 0x22dbec49a58>,
#  'terry': <gensim.models.keyedvectors.Vocab at 0x22dbec72860>,
#  'absurdly': <gensim.models.keyedvectors.Vocab at 0x22dbea8c7f0>,
#  'shameless': <gensim.models.keyedvectors.Vocab at 0x22dbfd9e4a8>,
#  'seuss': <gensim.models.keyedvectors.Vocab at 0x22dbec246d8>,
#  'racket': <gensim.models.keyedvectors.Vocab at 0x22dbeb04780>,
#  'surpasses': <gensim.models.keyedvectors.Vocab at 0x22dbec20da0>,
#  'jeans': <gensim.models.keyedvectors.Vocab at 0x22dbea639b0>,
#  'official': <gensim.models.keyedvectors.Vocab at 0x22dbea3ef28>,
#  'assistance': <gensim.models.keyedvectors.Vocab at 0x22dbea2ba20>,
#  'palmer': <gensim.models.keyedvectors.Vocab at 0x22dbebada20>,
#  'lucy': <gensim.models.keyedvectors.Vocab at 0x22dbea43a90>,
#  'umberto': <gensim.models.keyedvectors.Vocab at 0x22dbeac3390>,
#  'hip': <gensim.models.keyedvectors.Vocab at 0x22dbea479b0>,
#  'freezing': <gensim.models.keyedvectors.Vocab at 0x22dbfd9ab70>,
#  'amazon': <gensim.models.keyedvectors.Vocab at 0x22dbfdc89e8>,
#  'adaption': <gensim.models.keyedvectors.Vocab at 0x22dbed8e4e0>,
#  'originally': <gensim.models.keyedvectors.Vocab at 0x22dbebbada0>,
#  'orphaned': <gensim.models.keyedvectors.Vocab at 0x22dbec006d8>,
#  'mostel': <gensim.models.keyedvectors.Vocab at 0x22dbed13470>,
#  'bound': <gensim.models.keyedvectors.Vocab at 0x22dbfd8c390>,
#  'unlikable': <gensim.models.keyedvectors.Vocab at 0x22dbec77f98>,
#  'nolan': <gensim.models.keyedvectors.Vocab at 0x22dbed77fd0>,
#  'undead': <gensim.models.keyedvectors.Vocab at 0x22dbfd88320>,
#  'handled': <gensim.models.keyedvectors.Vocab at 0x22dbea9f080>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x22dbec2d7f0>,
#  'scandalous': <gensim.models.keyedvectors.Vocab at 0x22dbec85b38>,
#  'channeling': <gensim.models.keyedvectors.Vocab at 0x22dbea6c400>,
#  'davenport': <gensim.models.keyedvectors.Vocab at 0x22dbfdd9c88>,
#  'begins': <gensim.models.keyedvectors.Vocab at 0x22dbeb8ce80>,
#  'superficially': <gensim.models.keyedvectors.Vocab at 0x22dbd71b5f8>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x22dbed576d8>,
#  'resistance': <gensim.models.keyedvectors.Vocab at 0x22dbeb36b00>,
#  'winslet': <gensim.models.keyedvectors.Vocab at 0x22dbeaec240>,
#  'miner': <gensim.models.keyedvectors.Vocab at 0x22dbeb24080>,
#  'monkey': <gensim.models.keyedvectors.Vocab at 0x22dbecc9e48>,
#  'falco': <gensim.models.keyedvectors.Vocab at 0x22dbd705cf8>,
#  'partly': <gensim.models.keyedvectors.Vocab at 0x22dbeb44438>,
#  'diver': <gensim.models.keyedvectors.Vocab at 0x22dbd70e128>,
#  'cotton': <gensim.models.keyedvectors.Vocab at 0x22dbea7a828>,
#  'requiem': <gensim.models.keyedvectors.Vocab at 0x22dbecf7eb8>,
#  'caviezel': <gensim.models.keyedvectors.Vocab at 0x22dbeb48320>,
#  'skeleton': <gensim.models.keyedvectors.Vocab at 0x22dbeae8518>,
#  'cement': <gensim.models.keyedvectors.Vocab at 0x22dbeb96d68>,
#  'promised': <gensim.models.keyedvectors.Vocab at 0x22dbeac3908>,
#  'angst': <gensim.models.keyedvectors.Vocab at 0x22dbfd7ec18>,
#  'acceptance': <gensim.models.keyedvectors.Vocab at 0x22dbfdb19b0>,
#  'foolish': <gensim.models.keyedvectors.Vocab at 0x22dbfd7e3c8>,
#  'dubbed': <gensim.models.keyedvectors.Vocab at 0x22dbfdc8240>,
#  'masterfully': <gensim.models.keyedvectors.Vocab at 0x22dbfdb50f0>,
#  'katt': <gensim.models.keyedvectors.Vocab at 0x22dbec6d1d0>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x22dbecf31d0>,
#  'basics': <gensim.models.keyedvectors.Vocab at 0x22dbeb7ac50>,
#  'aim': <gensim.models.keyedvectors.Vocab at 0x22dbecb32e8>,
#  'jacqueline': <gensim.models.keyedvectors.Vocab at 0x22dbfd83c50>,
#  'lick': <gensim.models.keyedvectors.Vocab at 0x22dbec8d978>,
#  'awhile': <gensim.models.keyedvectors.Vocab at 0x22dbed25f60>,
#  'immense': <gensim.models.keyedvectors.Vocab at 0x22dbeb16d30>,
#  'sherlock': <gensim.models.keyedvectors.Vocab at 0x22dbebda208>,
#  'aishwarya': <gensim.models.keyedvectors.Vocab at 0x22dbed85c18>,
#  'coaster': <gensim.models.keyedvectors.Vocab at 0x22dbed8aba8>,
#  'dandy': <gensim.models.keyedvectors.Vocab at 0x22dbeb20160>,
#  'replicate': <gensim.models.keyedvectors.Vocab at 0x22dbea3e780>,
#  'dusk': <gensim.models.keyedvectors.Vocab at 0x22dbed69940>,
#  'norton': <gensim.models.keyedvectors.Vocab at 0x22dbea4b080>,
#  'sperm': <gensim.models.keyedvectors.Vocab at 0x22dbfd83748>,
#  'managed': <gensim.models.keyedvectors.Vocab at 0x22dbea43cc0>,
#  'peaceful': <gensim.models.keyedvectors.Vocab at 0x22dbea30860>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x22dbebad358>,
#  'breed': <gensim.models.keyedvectors.Vocab at 0x22dbea75be0>,
#  'showcased': <gensim.models.keyedvectors.Vocab at 0x22dbea7a7b8>,
#  'accept': <gensim.models.keyedvectors.Vocab at 0x22dbeaf2e80>,
#  'pranks': <gensim.models.keyedvectors.Vocab at 0x22dbed4e8d0>,
#  'dolphins': <gensim.models.keyedvectors.Vocab at 0x22dbeb44ba8>,
#  'master': <gensim.models.keyedvectors.Vocab at 0x22dbec12390>,
#  'mentions': <gensim.models.keyedvectors.Vocab at 0x22dbed777f0>,
#  'crashing': <gensim.models.keyedvectors.Vocab at 0x22dbea9abe0>,
#  'deus': <gensim.models.keyedvectors.Vocab at 0x22dbebc8160>,
#  'rejection': <gensim.models.keyedvectors.Vocab at 0x22dbebd6518>,
#  'splatter': <gensim.models.keyedvectors.Vocab at 0x22dbed9ccc0>,
#  'provocative': <gensim.models.keyedvectors.Vocab at 0x22dbeccd780>,
#  'beliefs': <gensim.models.keyedvectors.Vocab at 0x22dbec37358>,
#  'roll': <gensim.models.keyedvectors.Vocab at 0x22dbed69d68>,
#  'sang': <gensim.models.keyedvectors.Vocab at 0x22dbebdaa90>,
#  'perceive': <gensim.models.keyedvectors.Vocab at 0x22dbed65da0>,
#  'britt': <gensim.models.keyedvectors.Vocab at 0x22dbea71eb8>,
#  'surgery': <gensim.models.keyedvectors.Vocab at 0x22dbea59080>,
#  'docu': <gensim.models.keyedvectors.Vocab at 0x22dbea4b5f8>,
#  'herbert': <gensim.models.keyedvectors.Vocab at 0x22dbea95b38>,
#  'couples': <gensim.models.keyedvectors.Vocab at 0x22dbeabf160>,
#  'groan': <gensim.models.keyedvectors.Vocab at 0x22dbed1c198>,
#  'naming': <gensim.models.keyedvectors.Vocab at 0x22dbfd9e710>,
#  'inform': <gensim.models.keyedvectors.Vocab at 0x22dbed7cf60>,
#  'wounded': <gensim.models.keyedvectors.Vocab at 0x22dbea357f0>,
#  'carrying': <gensim.models.keyedvectors.Vocab at 0x22dbeb3ab38>,
#  'illusion': <gensim.models.keyedvectors.Vocab at 0x22dbd717e10>,
#  'belgium': <gensim.models.keyedvectors.Vocab at 0x22dbeb127b8>,
#  'memorial': <gensim.models.keyedvectors.Vocab at 0x22dbeb96e10>,
#  'fracture': <gensim.models.keyedvectors.Vocab at 0x22dbed5cef0>,
#  'scarecrows': <gensim.models.keyedvectors.Vocab at 0x22dbfdcd278>,
#  'impressed': <gensim.models.keyedvectors.Vocab at 0x22dbecb3978>,
#  'iturbi': <gensim.models.keyedvectors.Vocab at 0x22dbebba898>,
#  'lukas': <gensim.models.keyedvectors.Vocab at 0x22dbed7c470>,
#  'willie': <gensim.models.keyedvectors.Vocab at 0x22dbeca0dd8>,
#  'elsa': <gensim.models.keyedvectors.Vocab at 0x22dbed41940>,
#  'uplifting': <gensim.models.keyedvectors.Vocab at 0x22dbed8ada0>,
#  'slackers': <gensim.models.keyedvectors.Vocab at 0x22dbec7bc50>,
#  'regulars': <gensim.models.keyedvectors.Vocab at 0x22dbeca5fd0>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x22dbfd7e550>,
#  'gunfights': <gensim.models.keyedvectors.Vocab at 0x22dbec49278>,
#  'webber': <gensim.models.keyedvectors.Vocab at 0x22dbec89828>,
#  'copious': <gensim.models.keyedvectors.Vocab at 0x22dbed4eef0>,
#  'propaganda': <gensim.models.keyedvectors.Vocab at 0x22dbed53898>,
#  'looked': <gensim.models.keyedvectors.Vocab at 0x22dbead1860>,
#  'swank': <gensim.models.keyedvectors.Vocab at 0x22dbeb526a0>,
#  'admired': <gensim.models.keyedvectors.Vocab at 0x22dbea5f3c8>,
#  'rating': <gensim.models.keyedvectors.Vocab at 0x22dbecd3ba8>,
#  'arc': <gensim.models.keyedvectors.Vocab at 0x22dbea5f1d0>,
#  'dinosaurs': <gensim.models.keyedvectors.Vocab at 0x22dbec935f8>,
#  'unheard': <gensim.models.keyedvectors.Vocab at 0x22dbece9470>,
#  'tearful': <gensim.models.keyedvectors.Vocab at 0x22dbed21390>,
#  'daffy': <gensim.models.keyedvectors.Vocab at 0x22dbeb1a4e0>,
#  'shocked': <gensim.models.keyedvectors.Vocab at 0x22dbea59518>,
#  'explored': <gensim.models.keyedvectors.Vocab at 0x22dbea51048>,
#  'enormous': <gensim.models.keyedvectors.Vocab at 0x22dbed49128>,
#  'lusting': <gensim.models.keyedvectors.Vocab at 0x22dbea914e0>,
#  'taker': <gensim.models.keyedvectors.Vocab at 0x22dbeb52ef0>,
#  'themselves': <gensim.models.keyedvectors.Vocab at 0x22dbed013c8>,
#  'instance': <gensim.models.keyedvectors.Vocab at 0x22dbec24588>,
#  'titular': <gensim.models.keyedvectors.Vocab at 0x22dbeb323c8>,
#  'ambulance': <gensim.models.keyedvectors.Vocab at 0x22dbece16a0>,
#  'woodcock': <gensim.models.keyedvectors.Vocab at 0x22dbeb32be0>,
#  'logic': <gensim.models.keyedvectors.Vocab at 0x22dbfdd2940>,
#  'hating': <gensim.models.keyedvectors.Vocab at 0x22dbeaff358>,
#  'al': <gensim.models.keyedvectors.Vocab at 0x22dbea5f160>,
#  'covered': <gensim.models.keyedvectors.Vocab at 0x22dbed0eba8>,
#  'camilla': <gensim.models.keyedvectors.Vocab at 0x22dbeb96f60>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x22dbfd7a240>,
#  'contradictions': <gensim.models.keyedvectors.Vocab at 0x22dbfd7aba8>,
#  'hartnett': <gensim.models.keyedvectors.Vocab at 0x22dbfda8080>,
#  'attractions': <gensim.models.keyedvectors.Vocab at 0x22dbebe4940>,
#  'trapped': <gensim.models.keyedvectors.Vocab at 0x22dbeadf940>,
#  'descendant': <gensim.models.keyedvectors.Vocab at 0x22dbeccdf28>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x22dbead1278>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x22dbec7b0b8>,
#  'represented': <gensim.models.keyedvectors.Vocab at 0x22dbfdb58d0>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x22dbd71b940>,
#  'talky': <gensim.models.keyedvectors.Vocab at 0x22dbfdb18d0>,
#  'owe': <gensim.models.keyedvectors.Vocab at 0x22dbfdc30f0>,
#  'macmurray': <gensim.models.keyedvectors.Vocab at 0x22dbfda8b70>,
#  'guiding': <gensim.models.keyedvectors.Vocab at 0x22dbd70ed68>,
#  'sufficiently': <gensim.models.keyedvectors.Vocab at 0x22dbece1ba8>,
#  'ideal': <gensim.models.keyedvectors.Vocab at 0x22dbec16860>,
#  'extensive': <gensim.models.keyedvectors.Vocab at 0x22dbec0df60>,
#  'crystal': <gensim.models.keyedvectors.Vocab at 0x22dbeb48c18>,
#  'cleaned': <gensim.models.keyedvectors.Vocab at 0x22dbeb36c88>,
#  'alba': <gensim.models.keyedvectors.Vocab at 0x22dbec40c88>,
#  'tag': <gensim.models.keyedvectors.Vocab at 0x22dbfdcdc18>,
#  'biz': <gensim.models.keyedvectors.Vocab at 0x22dbeb52f60>,
#  'awesomely': <gensim.models.keyedvectors.Vocab at 0x22dbeb1a898>,
#  'isolation': <gensim.models.keyedvectors.Vocab at 0x22dbea95f28>,
#  'increases': <gensim.models.keyedvectors.Vocab at 0x22dbec803c8>,
#  'readily': <gensim.models.keyedvectors.Vocab at 0x22dbeae8748>,
#  'shiny': <gensim.models.keyedvectors.Vocab at 0x22dbfd8c198>,
#  'tied': <gensim.models.keyedvectors.Vocab at 0x22dbeaa7208>,
#  'terrifically': <gensim.models.keyedvectors.Vocab at 0x22dbfdb1080>,
#  'knowingly': <gensim.models.keyedvectors.Vocab at 0x22dbea275c0>,
#  'moves': <gensim.models.keyedvectors.Vocab at 0x22dbec80860>,
#  'l': <gensim.models.keyedvectors.Vocab at 0x22dbeb6cbe0>,
#  'richie': <gensim.models.keyedvectors.Vocab at 0x22dbfdb5a20>,
#  'garnered': <gensim.models.keyedvectors.Vocab at 0x22dbea67400>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x22dbed0e6a0>,
#  'bulldog': <gensim.models.keyedvectors.Vocab at 0x22dbea9f588>,
#  'cage': <gensim.models.keyedvectors.Vocab at 0x22dbecb76a0>,
#  'kidman': <gensim.models.keyedvectors.Vocab at 0x22dbed854e0>,
#  'fluid': <gensim.models.keyedvectors.Vocab at 0x22dbeba4cc0>,
#  'cellphone': <gensim.models.keyedvectors.Vocab at 0x22dbeb72588>,
#  'gripe': <gensim.models.keyedvectors.Vocab at 0x22dbed3cef0>,
#  'thinks': <gensim.models.keyedvectors.Vocab at 0x22dbea55ac8>,
#  'decidedly': <gensim.models.keyedvectors.Vocab at 0x22dbed85ef0>,
#  'bio': <gensim.models.keyedvectors.Vocab at 0x22dbed136a0>,
#  'newhart': <gensim.models.keyedvectors.Vocab at 0x22dbea9f630>,
#  'inventions': <gensim.models.keyedvectors.Vocab at 0x22dbec09400>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x22dbeb6c828>,
#  'contest': <gensim.models.keyedvectors.Vocab at 0x22dbebd2a58>,
#  'dictionary': <gensim.models.keyedvectors.Vocab at 0x22dbebd6400>,
#  'voyeurism': <gensim.models.keyedvectors.Vocab at 0x22dbea47240>,
#  'extensively': <gensim.models.keyedvectors.Vocab at 0x22dbd713a90>,
#  'tolerance': <gensim.models.keyedvectors.Vocab at 0x22dbed93978>,
#  'titanic': <gensim.models.keyedvectors.Vocab at 0x22dbec2d9b0>,
#  'newton': <gensim.models.keyedvectors.Vocab at 0x22dbea7f5f8>,
#  'division': <gensim.models.keyedvectors.Vocab at 0x22dbeb6c668>,
#  'humiliating': <gensim.models.keyedvectors.Vocab at 0x22dbebadb00>,
#  'deprived': <gensim.models.keyedvectors.Vocab at 0x22dbed41be0>,
#  'tasteful': <gensim.models.keyedvectors.Vocab at 0x22dbec20e10>,
#  'whipping': <gensim.models.keyedvectors.Vocab at 0x22dbed419b0>,
#  'relation': <gensim.models.keyedvectors.Vocab at 0x22dbeba8f28>,
#  'clich': <gensim.models.keyedvectors.Vocab at 0x22dbfdc3ac8>,
#  'battlestar': <gensim.models.keyedvectors.Vocab at 0x22dbeaac630>,
#  'realises': <gensim.models.keyedvectors.Vocab at 0x22dbec40c50>,
#  'digs': <gensim.models.keyedvectors.Vocab at 0x22dbec8d208>,
#  'ifans': <gensim.models.keyedvectors.Vocab at 0x22dbeb9a7b8>,
#  'nurse': <gensim.models.keyedvectors.Vocab at 0x22dbeb04588>,
#  'lion': <gensim.models.keyedvectors.Vocab at 0x22dbfdbe898>,
#  'borders': <gensim.models.keyedvectors.Vocab at 0x22dbecc9208>,
#  'remakes': <gensim.models.keyedvectors.Vocab at 0x22dbeb52710>,
#  'shade': <gensim.models.keyedvectors.Vocab at 0x22dbeb24940>,
#  'dundee': <gensim.models.keyedvectors.Vocab at 0x22dbeb247b8>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x22dbeb0cb38>,
#  'diversion': <gensim.models.keyedvectors.Vocab at 0x22dbed25d68>,
#  'dub': <gensim.models.keyedvectors.Vocab at 0x22dbeac3ba8>,
#  'writer': <gensim.models.keyedvectors.Vocab at 0x22dbea91240>,
#  'meg': <gensim.models.keyedvectors.Vocab at 0x22dbeb6cf98>,
#  'perverted': <gensim.models.keyedvectors.Vocab at 0x22dbec695c0>,
#  'corners': <gensim.models.keyedvectors.Vocab at 0x22dbec12f28>,
#  'slavery': <gensim.models.keyedvectors.Vocab at 0x22dbed05f28>,
#  'inserted': <gensim.models.keyedvectors.Vocab at 0x22dbeb4ce48>,
#  'cathartic': <gensim.models.keyedvectors.Vocab at 0x22dbece9668>,
#  'rates': <gensim.models.keyedvectors.Vocab at 0x22dbea9fa58>,
#  'hauntingly': <gensim.models.keyedvectors.Vocab at 0x22dbec0d6a0>,
#  'charms': <gensim.models.keyedvectors.Vocab at 0x22dbed697b8>,
#  'possessions': <gensim.models.keyedvectors.Vocab at 0x22dbebe05f8>,
#  'meticulously': <gensim.models.keyedvectors.Vocab at 0x22dbd70e748>,
#  'collins': <gensim.models.keyedvectors.Vocab at 0x22dbfd834e0>,
#  'sort': <gensim.models.keyedvectors.Vocab at 0x22dbeb0cc50>,
#  'custom': <gensim.models.keyedvectors.Vocab at 0x22dbea551d0>,
#  'cinematography': <gensim.models.keyedvectors.Vocab at 0x22dbed73c18>,
#  'remembers': <gensim.models.keyedvectors.Vocab at 0x22dbeb522b0>,
#  'invest': <gensim.models.keyedvectors.Vocab at 0x22dbea9f1d0>,
#  'philippines': <gensim.models.keyedvectors.Vocab at 0x22dbebd2e10>,
#  'husbands': <gensim.models.keyedvectors.Vocab at 0x22dbfd9e828>,
#  'idaho': <gensim.models.keyedvectors.Vocab at 0x22dbfdb5b00>,
#  'mike': <gensim.models.keyedvectors.Vocab at 0x22dbea9fe80>,
#  'relentless': <gensim.models.keyedvectors.Vocab at 0x22dbeaa3a58>,
#  'sarandon': <gensim.models.keyedvectors.Vocab at 0x22dbeb32cf8>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x22dbeb5a9b0>,
#  'cliche': <gensim.models.keyedvectors.Vocab at 0x22dbec77da0>,
#  'purchase': <gensim.models.keyedvectors.Vocab at 0x22dbfdba278>,
#  'auteur': <gensim.models.keyedvectors.Vocab at 0x22dbebe0b00>,
#  'superstar': <gensim.models.keyedvectors.Vocab at 0x22dbec93278>,
#  'dominating': <gensim.models.keyedvectors.Vocab at 0x22dbed5ccc0>,
#  'lindsey': <gensim.models.keyedvectors.Vocab at 0x22dbed1c518>,
#  'afoul': <gensim.models.keyedvectors.Vocab at 0x22dbd709c18>,
#  'freed': <gensim.models.keyedvectors.Vocab at 0x22dbec49d68>,
#  'inescapable': <gensim.models.keyedvectors.Vocab at 0x22dbeb9a400>,
#  'masterson': <gensim.models.keyedvectors.Vocab at 0x22dbed3ca20>,
#  'passes': <gensim.models.keyedvectors.Vocab at 0x22dbea9f2b0>,
#  'tilda': <gensim.models.keyedvectors.Vocab at 0x22dbea8cd68>,
#  'andromeda': <gensim.models.keyedvectors.Vocab at 0x22dbed49da0>,
#  'sacrifice': <gensim.models.keyedvectors.Vocab at 0x22dbea4bbe0>,
#  'hijacking': <gensim.models.keyedvectors.Vocab at 0x22dbed4ee10>,
#  'hearted': <gensim.models.keyedvectors.Vocab at 0x22dbec5b6d8>,
#  'privileged': <gensim.models.keyedvectors.Vocab at 0x22dbeb88e80>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x22dbfd9e898>,
#  'preaching': <gensim.models.keyedvectors.Vocab at 0x22dbfdd9080>,
#  'linus': <gensim.models.keyedvectors.Vocab at 0x22dbecc5550>,
#  'bumps': <gensim.models.keyedvectors.Vocab at 0x22dbeaff940>,
#  'hyde': <gensim.models.keyedvectors.Vocab at 0x22dbebda240>,
#  'unscathed': <gensim.models.keyedvectors.Vocab at 0x22dbd7252e8>,
#  'spotting': <gensim.models.keyedvectors.Vocab at 0x22dbec802b0>,
#  'candid': <gensim.models.keyedvectors.Vocab at 0x22dbec7b5c0>,
#  'warrants': <gensim.models.keyedvectors.Vocab at 0x22dbecad5c0>,
#  'chevalier': <gensim.models.keyedvectors.Vocab at 0x22dbed499e8>,
#  'befriended': <gensim.models.keyedvectors.Vocab at 0x22dbeb680f0>,
#  'brute': <gensim.models.keyedvectors.Vocab at 0x22dbeb92cf8>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x22dbed0e048>,
#  'currie': <gensim.models.keyedvectors.Vocab at 0x22dbea7f240>,
#  'profit': <gensim.models.keyedvectors.Vocab at 0x22dbeafa4e0>,
#  'helena': <gensim.models.keyedvectors.Vocab at 0x22dbfd88908>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x22dbea9f0b8>,
#  'frederick': <gensim.models.keyedvectors.Vocab at 0x22dbec4dcf8>,
#  'joins': <gensim.models.keyedvectors.Vocab at 0x22dbfd9ab38>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x22dbea5ff60>,
#  'ray': <gensim.models.keyedvectors.Vocab at 0x22dbeaa7b00>,
#  'oldest': <gensim.models.keyedvectors.Vocab at 0x22dbeab54a8>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x22dbed37b00>,
#  'lore': <gensim.models.keyedvectors.Vocab at 0x22dbeb7a4a8>,
#  'sharma': <gensim.models.keyedvectors.Vocab at 0x22dbed29518>,
#  'attentions': <gensim.models.keyedvectors.Vocab at 0x22dbecf70f0>,
#  'piercing': <gensim.models.keyedvectors.Vocab at 0x22dbea7feb8>,
#  'saints': <gensim.models.keyedvectors.Vocab at 0x22dbec1bd30>,
#  'compete': <gensim.models.keyedvectors.Vocab at 0x22dbecf7ef0>,
#  'define': <gensim.models.keyedvectors.Vocab at 0x22dbed4e128>,
#  'compensation': <gensim.models.keyedvectors.Vocab at 0x22dbfd88b38>,
#  'illiterate': <gensim.models.keyedvectors.Vocab at 0x22dbece18d0>,
#  'scheming': <gensim.models.keyedvectors.Vocab at 0x22dbec3b0b8>,
#  'newspapers': <gensim.models.keyedvectors.Vocab at 0x22dbecf3f98>,
#  'knit': <gensim.models.keyedvectors.Vocab at 0x22dbeadfbe0>,
#  'revolutionary': <gensim.models.keyedvectors.Vocab at 0x22dbebf2f28>,
#  'gothic': <gensim.models.keyedvectors.Vocab at 0x22dbea395f8>,
#  'flirting': <gensim.models.keyedvectors.Vocab at 0x22dbfd9aef0>,
#  'painfully': <gensim.models.keyedvectors.Vocab at 0x22dbead6a20>,
#  'delivers': <gensim.models.keyedvectors.Vocab at 0x22dbec69898>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x22dbeca9198>,
#  'spending': <gensim.models.keyedvectors.Vocab at 0x22dbed25dd8>,
#  'formed': <gensim.models.keyedvectors.Vocab at 0x22dbeb44320>,
#  'robbie': <gensim.models.keyedvectors.Vocab at 0x22dbec2de80>,
#  'technical': <gensim.models.keyedvectors.Vocab at 0x22dbd729400>,
#  'scooby': <gensim.models.keyedvectors.Vocab at 0x22dbfddd0b8>,
#  'serene': <gensim.models.keyedvectors.Vocab at 0x22dbec93c18>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x22dbfda3f28>,
#  'abe': <gensim.models.keyedvectors.Vocab at 0x22dbecbba20>,
#  'plain': <gensim.models.keyedvectors.Vocab at 0x22dbed332b0>,
#  'garcia': <gensim.models.keyedvectors.Vocab at 0x22dbebc4d68>,
#  'spreads': <gensim.models.keyedvectors.Vocab at 0x22dbea71470>,
#  'donkey': <gensim.models.keyedvectors.Vocab at 0x22dbeb68a20>,
#  'flipping': <gensim.models.keyedvectors.Vocab at 0x22dbeb80b00>,
#  'hustler': <gensim.models.keyedvectors.Vocab at 0x22dbeb0c320>,
#  'nobody': <gensim.models.keyedvectors.Vocab at 0x22dbecad160>,
#  'torn': <gensim.models.keyedvectors.Vocab at 0x22dbec933c8>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x22dbecbb0f0>,
#  'apples': <gensim.models.keyedvectors.Vocab at 0x22dbd72ec18>,
#  'paltrow': <gensim.models.keyedvectors.Vocab at 0x22dbd713e10>,
#  'sharp': <gensim.models.keyedvectors.Vocab at 0x22dbeb84898>,
#  'goo': <gensim.models.keyedvectors.Vocab at 0x22dbea9a9e8>,
#  'jeffrey': <gensim.models.keyedvectors.Vocab at 0x22dbea35198>,
#  'boobs': <gensim.models.keyedvectors.Vocab at 0x22dbed3c908>,
#  'bettany': <gensim.models.keyedvectors.Vocab at 0x22dbeb68390>,
#  'jumbo': <gensim.models.keyedvectors.Vocab at 0x22dbed45320>,
#  'edition': <gensim.models.keyedvectors.Vocab at 0x22dbeaeccf8>,
#  'travesty': <gensim.models.keyedvectors.Vocab at 0x22dbecf7ba8>,
#  'absorbing': <gensim.models.keyedvectors.Vocab at 0x22dbeb523c8>,
#  'harrowing': <gensim.models.keyedvectors.Vocab at 0x22dbeae8128>,
#  'scan': <gensim.models.keyedvectors.Vocab at 0x22dbeb7a748>,
#  'hmm': <gensim.models.keyedvectors.Vocab at 0x22dbeb36cf8>,
#  'motion': <gensim.models.keyedvectors.Vocab at 0x22dbea7ae10>,
#  'hearse': <gensim.models.keyedvectors.Vocab at 0x22dbeb52b00>,
#  'pasolini': <gensim.models.keyedvectors.Vocab at 0x22dbeb72b70>,
#  'pristine': <gensim.models.keyedvectors.Vocab at 0x22dbecbb550>,
#  'wakes': <gensim.models.keyedvectors.Vocab at 0x22dbeada4a8>,
#  'bravura': <gensim.models.keyedvectors.Vocab at 0x22dbeaa7470>,
#  'schildkraut': <gensim.models.keyedvectors.Vocab at 0x22dbfd9aa58>,
#  'linking': <gensim.models.keyedvectors.Vocab at 0x22dbfda8908>,
#  'magnolia': <gensim.models.keyedvectors.Vocab at 0x22dbfd91cc0>,
#  'denise': <gensim.models.keyedvectors.Vocab at 0x22dbec00198>,
#  'downhill': <gensim.models.keyedvectors.Vocab at 0x22dbeb44d68>,
#  'wine': <gensim.models.keyedvectors.Vocab at 0x22dbeabf4e0>,
#  'singer': <gensim.models.keyedvectors.Vocab at 0x22dbeba8dd8>,
#  'comprehensive': <gensim.models.keyedvectors.Vocab at 0x22dbeadf438>,
#  'liquid': <gensim.models.keyedvectors.Vocab at 0x22dbfdd5b00>,
#  'haphazard': <gensim.models.keyedvectors.Vocab at 0x22dbfd7ab00>,
#  'misfortune': <gensim.models.keyedvectors.Vocab at 0x22dbecbbba8>,
#  'commando': <gensim.models.keyedvectors.Vocab at 0x22dbeb209e8>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x22dbea3ef98>,
#  'miniature': <gensim.models.keyedvectors.Vocab at 0x22dbeb0cd68>,
#  'mountain': <gensim.models.keyedvectors.Vocab at 0x22dbfdac748>,
#  'anticipation': <gensim.models.keyedvectors.Vocab at 0x22dbed09b70>,
#  'applegate': <gensim.models.keyedvectors.Vocab at 0x22dbea5fd30>,
#  'ivory': <gensim.models.keyedvectors.Vocab at 0x22dbfd9e8d0>,
#  'places': <gensim.models.keyedvectors.Vocab at 0x22dbec6d358>,
#  'runaway': <gensim.models.keyedvectors.Vocab at 0x22dbed85278>,
#  'redundant': <gensim.models.keyedvectors.Vocab at 0x22dbeb8c908>,
#  'consisting': <gensim.models.keyedvectors.Vocab at 0x22dbd709518>,
#  'merciless': <gensim.models.keyedvectors.Vocab at 0x22dbecc9e10>,
#  'busby': <gensim.models.keyedvectors.Vocab at 0x22dbeca9b70>,
#  'deserving': <gensim.models.keyedvectors.Vocab at 0x22dbebba8d0>,
#  'advocate': <gensim.models.keyedvectors.Vocab at 0x22dbeb52518>,
#  'whitaker': <gensim.models.keyedvectors.Vocab at 0x22dbeb08f60>,
#  'systematically': <gensim.models.keyedvectors.Vocab at 0x22dbec126a0>,
#  'boris': <gensim.models.keyedvectors.Vocab at 0x22dbeb48f28>,
#  'betsy': <gensim.models.keyedvectors.Vocab at 0x22dbed01b70>,
#  'mounted': <gensim.models.keyedvectors.Vocab at 0x22dbec12240>,
#  'sassy': <gensim.models.keyedvectors.Vocab at 0x22dbead68d0>,
#  'raising': <gensim.models.keyedvectors.Vocab at 0x22dbeac8d30>,
#  'elephants': <gensim.models.keyedvectors.Vocab at 0x22dbeb884a8>,
#  'intrepid': <gensim.models.keyedvectors.Vocab at 0x22dbed53978>,
#  'bosses': <gensim.models.keyedvectors.Vocab at 0x22dbeaa3128>,
#  'rushed': <gensim.models.keyedvectors.Vocab at 0x22dbec5b6a0>,
#  'hallway': <gensim.models.keyedvectors.Vocab at 0x22dbec77828>,
#  'bourgeoisie': <gensim.models.keyedvectors.Vocab at 0x22dbed69eb8>,
#  'dogme': <gensim.models.keyedvectors.Vocab at 0x22dbecbb4e0>,
#  'teen': <gensim.models.keyedvectors.Vocab at 0x22dbeb92a90>,
#  'footsteps': <gensim.models.keyedvectors.Vocab at 0x22dbecf3278>,
#  'yeah': <gensim.models.keyedvectors.Vocab at 0x22dbeac8d68>,
#  'wretched': <gensim.models.keyedvectors.Vocab at 0x22dbeb96898>,
#  'suckers': <gensim.models.keyedvectors.Vocab at 0x22dbebd25f8>,
#  'innocuous': <gensim.models.keyedvectors.Vocab at 0x22dbd72e668>,
#  'co': <gensim.models.keyedvectors.Vocab at 0x22dbead1240>,
#  'unimpressive': <gensim.models.keyedvectors.Vocab at 0x22dbeca5630>,
#  'metaphor': <gensim.models.keyedvectors.Vocab at 0x22dbebf2c50>,
#  'beginnings': <gensim.models.keyedvectors.Vocab at 0x22dbecc52e8>,
#  'fore': <gensim.models.keyedvectors.Vocab at 0x22dbecd7828>,
#  'roaming': <gensim.models.keyedvectors.Vocab at 0x22dbd70e4a8>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x22dbeaec048>,
#  'sooner': <gensim.models.keyedvectors.Vocab at 0x22dbea4b6d8>,
#  'resulted': <gensim.models.keyedvectors.Vocab at 0x22dbea87a90>,
#  'personified': <gensim.models.keyedvectors.Vocab at 0x22dbec52048>,
#  'employee': <gensim.models.keyedvectors.Vocab at 0x22dbfdd9cf8>,
#  'sledgehammer': <gensim.models.keyedvectors.Vocab at 0x22dbea23fd0>,
#  'childhood': <gensim.models.keyedvectors.Vocab at 0x22dbed6e4a8>,
#  'abandoned': <gensim.models.keyedvectors.Vocab at 0x22dbfd8ca58>,
#  'tuck': <gensim.models.keyedvectors.Vocab at 0x22dbeaec518>,
#  'unless': <gensim.models.keyedvectors.Vocab at 0x22dbecb39b0>,
#  'offs': <gensim.models.keyedvectors.Vocab at 0x22dbeb12470>,
#  'tension': <gensim.models.keyedvectors.Vocab at 0x22dbfd88390>,
#  'iowa': <gensim.models.keyedvectors.Vocab at 0x22dbfdcd748>,
#  'tense': <gensim.models.keyedvectors.Vocab at 0x22dbeb960b8>,
#  'powerhouse': <gensim.models.keyedvectors.Vocab at 0x22dbebed1d0>,
#  'civilized': <gensim.models.keyedvectors.Vocab at 0x22dbeaba128>,
#  'equipped': <gensim.models.keyedvectors.Vocab at 0x22dbec3bb70>,
#  'clothes': <gensim.models.keyedvectors.Vocab at 0x22dbfdc39e8>,
#  'rudolf': <gensim.models.keyedvectors.Vocab at 0x22dbeb40898>,
#  'junkies': <gensim.models.keyedvectors.Vocab at 0x22dbea595c0>,
#  'yen': <gensim.models.keyedvectors.Vocab at 0x22dbeabac18>,
#  'overload': <gensim.models.keyedvectors.Vocab at 0x22dbec80e48>,
#  'sant': <gensim.models.keyedvectors.Vocab at 0x22dbea47390>,
#  'captivate': <gensim.models.keyedvectors.Vocab at 0x22dbfdb1ef0>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x22dbec5b668>,
#  'glory': <gensim.models.keyedvectors.Vocab at 0x22dbeaffac8>,
#  'unemotional': <gensim.models.keyedvectors.Vocab at 0x22dbeb086d8>,
#  'marin': <gensim.models.keyedvectors.Vocab at 0x22dbeb2c470>,
#  'narrow': <gensim.models.keyedvectors.Vocab at 0x22dbebb2a58>,
#  'shockingly': <gensim.models.keyedvectors.Vocab at 0x22dbeb525c0>,
#  'timeless': <gensim.models.keyedvectors.Vocab at 0x22dbd705ba8>,
#  'encountered': <gensim.models.keyedvectors.Vocab at 0x22dbfdaceb8>,
#  'intellect': <gensim.models.keyedvectors.Vocab at 0x22dbecc0cf8>,
#  'sanity': <gensim.models.keyedvectors.Vocab at 0x22dbeb40e10>,
#  'neighbours': <gensim.models.keyedvectors.Vocab at 0x22dbeac3fd0>,
#  'slime': <gensim.models.keyedvectors.Vocab at 0x22dbeab5f98>,
#  'isabel': <gensim.models.keyedvectors.Vocab at 0x22dbea7f080>,
#  'warn': <gensim.models.keyedvectors.Vocab at 0x22dbed33588>,
#  'olsen': <gensim.models.keyedvectors.Vocab at 0x22dbea23908>,
#  'mixture': <gensim.models.keyedvectors.Vocab at 0x22dbfdc8358>,
#  'lilly': <gensim.models.keyedvectors.Vocab at 0x22dbed45160>,
#  'award': <gensim.models.keyedvectors.Vocab at 0x22dbeca0b38>,
#  'protagonist': <gensim.models.keyedvectors.Vocab at 0x22dbed53438>,
#  'babble': <gensim.models.keyedvectors.Vocab at 0x22dbecc0668>,
#  'ennio': <gensim.models.keyedvectors.Vocab at 0x22dbed25828>,
#  'cracking': <gensim.models.keyedvectors.Vocab at 0x22dbecfb320>,
#  'ditto': <gensim.models.keyedvectors.Vocab at 0x22dbec72630>,
#  'blends': <gensim.models.keyedvectors.Vocab at 0x22dbeb162e8>,
#  'vice': <gensim.models.keyedvectors.Vocab at 0x22dbed81630>,
#  'assumptions': <gensim.models.keyedvectors.Vocab at 0x22dbea9f4a8>,
#  'makings': <gensim.models.keyedvectors.Vocab at 0x22dbeb24c88>,
#  'youtube': <gensim.models.keyedvectors.Vocab at 0x22dbed21b00>,
#  'lamarr': <gensim.models.keyedvectors.Vocab at 0x22dbeb56cc0>,
#  'nearly': <gensim.models.keyedvectors.Vocab at 0x22dbfdcdd30>,
#  'kissing': <gensim.models.keyedvectors.Vocab at 0x22dbec93f28>,
#  'ritter': <gensim.models.keyedvectors.Vocab at 0x22dbfdbeba8>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x22dbfdd2748>,
#  'etting': <gensim.models.keyedvectors.Vocab at 0x22dbec97a90>,
#  'towers': <gensim.models.keyedvectors.Vocab at 0x22dbec00550>,
#  'sloppily': <gensim.models.keyedvectors.Vocab at 0x22dbeadf3c8>,
#  'burn': <gensim.models.keyedvectors.Vocab at 0x22dbead1780>,
#  'senses': <gensim.models.keyedvectors.Vocab at 0x22dbfd95ef0>,
#  'arctic': <gensim.models.keyedvectors.Vocab at 0x22dbeafafd0>,
#  'implication': <gensim.models.keyedvectors.Vocab at 0x22dbea59ef0>,
#  'foreshadowing': <gensim.models.keyedvectors.Vocab at 0x22dbeabf6d8>,
#  'justify': <gensim.models.keyedvectors.Vocab at 0x22dbec85390>,
#  'scout': <gensim.models.keyedvectors.Vocab at 0x22dbec8dda0>,
#  'forum': <gensim.models.keyedvectors.Vocab at 0x22dbece9c88>,
#  'anchor': <gensim.models.keyedvectors.Vocab at 0x22dbed012b0>,
#  'party': <gensim.models.keyedvectors.Vocab at 0x22dbeac8f60>,
#  'bump': <gensim.models.keyedvectors.Vocab at 0x22dbec9bbe0>,
#  'widower': <gensim.models.keyedvectors.Vocab at 0x22dbd71b908>,
#  'poisoning': <gensim.models.keyedvectors.Vocab at 0x22dbeb0ca90>,
#  'pal': <gensim.models.keyedvectors.Vocab at 0x22dbeb88400>,
#  'formation': <gensim.models.keyedvectors.Vocab at 0x22dbea39a90>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x22dbece59b0>,
#  'bitter': <gensim.models.keyedvectors.Vocab at 0x22dbebd2be0>,
#  'ok': <gensim.models.keyedvectors.Vocab at 0x22dbea9f278>,
#  'tracking': <gensim.models.keyedvectors.Vocab at 0x22dbeba44e0>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x22dbeb92fd0>,
#  'nadia': <gensim.models.keyedvectors.Vocab at 0x22dbeb88c50>,
#  'finney': <gensim.models.keyedvectors.Vocab at 0x22dbfdbe0f0>,
#  'attain': <gensim.models.keyedvectors.Vocab at 0x22dbfd8c828>,
#  'holy': <gensim.models.keyedvectors.Vocab at 0x22dbed214e0>,
#  'glen': <gensim.models.keyedvectors.Vocab at 0x22dbfda3cc0>,
#  'crazed': <gensim.models.keyedvectors.Vocab at 0x22dbeb045f8>,
#  'overshadowed': <gensim.models.keyedvectors.Vocab at 0x22dbec29eb8>,
#  'volatile': <gensim.models.keyedvectors.Vocab at 0x22dbec37748>,
#  'festivals': <gensim.models.keyedvectors.Vocab at 0x22dbfd75208>,
#  'nt': <gensim.models.keyedvectors.Vocab at 0x22dbea9f978>,
#  'dissolves': <gensim.models.keyedvectors.Vocab at 0x22dbeb08748>,
#  'glimpse': <gensim.models.keyedvectors.Vocab at 0x22dbea71518>,
#  'inane': <gensim.models.keyedvectors.Vocab at 0x22dbeae8f98>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x22dbeb2c8d0>,
#  'matt': <gensim.models.keyedvectors.Vocab at 0x22dbec937f0>,
#  'uninteresting': <gensim.models.keyedvectors.Vocab at 0x22dbfd7af98>,
#  'drift': <gensim.models.keyedvectors.Vocab at 0x22dbebadf60>,
#  'versus': <gensim.models.keyedvectors.Vocab at 0x22dbea87198>,
#  'seventeen': <gensim.models.keyedvectors.Vocab at 0x22dbec9ba90>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x22dbebd6e10>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x22dbfdbaeb8>,
#  'lorre': <gensim.models.keyedvectors.Vocab at 0x22dbebda080>,
#  'comedienne': <gensim.models.keyedvectors.Vocab at 0x22dbeaecc50>,
#  'bunny': <gensim.models.keyedvectors.Vocab at 0x22dbecbb278>,
#  'codes': <gensim.models.keyedvectors.Vocab at 0x22dbec49dd8>,
#  'attempted': <gensim.models.keyedvectors.Vocab at 0x22dbea59ba8>,
#  'hank': <gensim.models.keyedvectors.Vocab at 0x22dbed2edd8>,
#  'sided': <gensim.models.keyedvectors.Vocab at 0x22dbfd95320>,
#  'syndicate': <gensim.models.keyedvectors.Vocab at 0x22dbec12dd8>,
#  'dahmer': <gensim.models.keyedvectors.Vocab at 0x22dbea71320>,
#  'dolby': <gensim.models.keyedvectors.Vocab at 0x22dbeb9a518>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x22dbeb0cd30>,
#  'flair': <gensim.models.keyedvectors.Vocab at 0x22dbed77f98>,
#  'bastards': <gensim.models.keyedvectors.Vocab at 0x22dbeb766a0>,
#  'specialist': <gensim.models.keyedvectors.Vocab at 0x22dbed4ecc0>,
#  'haired': <gensim.models.keyedvectors.Vocab at 0x22dbfda3898>,
#  'comical': <gensim.models.keyedvectors.Vocab at 0x22dbece5518>,
#  'doubts': <gensim.models.keyedvectors.Vocab at 0x22dbeb3a278>,
#  'rife': <gensim.models.keyedvectors.Vocab at 0x22dbed535f8>,
#  'household': <gensim.models.keyedvectors.Vocab at 0x22dbea236a0>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x22dbec85400>,
#  'squeeze': <gensim.models.keyedvectors.Vocab at 0x22dbec5b518>,
#  'footloose': <gensim.models.keyedvectors.Vocab at 0x22dbd709e10>,
#  'firing': <gensim.models.keyedvectors.Vocab at 0x22dbfdd2c50>,
#  'genuinely': <gensim.models.keyedvectors.Vocab at 0x22dbeadaa58>,
#  'gangsta': <gensim.models.keyedvectors.Vocab at 0x22dbea47ef0>,
#  'plug': <gensim.models.keyedvectors.Vocab at 0x22dbeaec5c0>,
#  'grotesque': <gensim.models.keyedvectors.Vocab at 0x22dbebc8550>,
#  'corey': <gensim.models.keyedvectors.Vocab at 0x22dbeba42b0>,
#  'ad': <gensim.models.keyedvectors.Vocab at 0x22dbeb36b38>,
#  'evident': <gensim.models.keyedvectors.Vocab at 0x22dbecf3c88>,
#  'glorious': <gensim.models.keyedvectors.Vocab at 0x22dbeba4278>,
#  'gibson': <gensim.models.keyedvectors.Vocab at 0x22dbece55c0>,
#  'commenter': <gensim.models.keyedvectors.Vocab at 0x22dbea35518>,
#  'fantastical': <gensim.models.keyedvectors.Vocab at 0x22dbed850f0>,
#  'proposed': <gensim.models.keyedvectors.Vocab at 0x22dbeaf2a58>,
#  'spared': <gensim.models.keyedvectors.Vocab at 0x22dbed17908>,
#  'act': <gensim.models.keyedvectors.Vocab at 0x22dbfda35f8>,
#  'johnston': <gensim.models.keyedvectors.Vocab at 0x22dbeb8c278>,
#  'teenage': <gensim.models.keyedvectors.Vocab at 0x22dbea51978>,
#  'threats': <gensim.models.keyedvectors.Vocab at 0x22dbd72e160>,
#  'malik': <gensim.models.keyedvectors.Vocab at 0x22dbebc0f98>,
#  'shocking': <gensim.models.keyedvectors.Vocab at 0x22dbfdacd68>,
#  'journalists': <gensim.models.keyedvectors.Vocab at 0x22dbeb7aa58>,
#  'anticipated': <gensim.models.keyedvectors.Vocab at 0x22dbed77668>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x22dbea9a7b8>,
#  'relating': <gensim.models.keyedvectors.Vocab at 0x22dbecf3d68>,
#  'rocks': <gensim.models.keyedvectors.Vocab at 0x22dbea91dd8>,
#  'smokes': <gensim.models.keyedvectors.Vocab at 0x22dbeab50f0>,
#  'spoon': <gensim.models.keyedvectors.Vocab at 0x22dbecb7a90>,
#  'aspires': <gensim.models.keyedvectors.Vocab at 0x22dbeb32b38>,
#  'resembles': <gensim.models.keyedvectors.Vocab at 0x22dbed05be0>,
#  'ease': <gensim.models.keyedvectors.Vocab at 0x22dbeaa3b38>,
#  'convent': <gensim.models.keyedvectors.Vocab at 0x22dbfdbe208>,
#  'tuesday': <gensim.models.keyedvectors.Vocab at 0x22dbec128d0>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x22dbfd95f28>,
#  'geez': <gensim.models.keyedvectors.Vocab at 0x22dbfd8c748>,
#  'scott': <gensim.models.keyedvectors.Vocab at 0x22dbed210f0>,
#  'insistence': <gensim.models.keyedvectors.Vocab at 0x22dbebc4eb8>,
#  'hawn': <gensim.models.keyedvectors.Vocab at 0x22dbeb1ae80>,
#  'crusoe': <gensim.models.keyedvectors.Vocab at 0x22dbed0e4e0>,
#  'undeniably': <gensim.models.keyedvectors.Vocab at 0x22dbecd7748>,
#  'machete': <gensim.models.keyedvectors.Vocab at 0x22dbd717860>,
#  'ordering': <gensim.models.keyedvectors.Vocab at 0x22dbfdcdd68>,
#  'mulder': <gensim.models.keyedvectors.Vocab at 0x22dbeaacba8>,
#  'misty': <gensim.models.keyedvectors.Vocab at 0x22dbec0dcc0>,
#  'sudden': <gensim.models.keyedvectors.Vocab at 0x22dbed0e5c0>,
#  'shopping': <gensim.models.keyedvectors.Vocab at 0x22dbebed400>,
#  'someplace': <gensim.models.keyedvectors.Vocab at 0x22dbfdaca58>,
#  'burt': <gensim.models.keyedvectors.Vocab at 0x22dbed13400>,
#  'arse': <gensim.models.keyedvectors.Vocab at 0x22dbeb16fd0>,
#  'tourists': <gensim.models.keyedvectors.Vocab at 0x22dbfdba438>,
#  'parallels': <gensim.models.keyedvectors.Vocab at 0x22dbece1160>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x22dbec16eb8>,
#  'interviews': <gensim.models.keyedvectors.Vocab at 0x22dbd70ea20>,
#  'benchmark': <gensim.models.keyedvectors.Vocab at 0x22dbeb4c0f0>,
#  'tropical': <gensim.models.keyedvectors.Vocab at 0x22dbec320f0>,
#  'motive': <gensim.models.keyedvectors.Vocab at 0x22dbecdb908>,
#  'conveniently': <gensim.models.keyedvectors.Vocab at 0x22dbeba8860>,
#  'public': <gensim.models.keyedvectors.Vocab at 0x22dbeb88320>,
#  'shoved': <gensim.models.keyedvectors.Vocab at 0x22dbec5b898>,
#  'orville': <gensim.models.keyedvectors.Vocab at 0x22dbec00048>,
#  'silliness': <gensim.models.keyedvectors.Vocab at 0x22dbed570b8>,
#  'solar': <gensim.models.keyedvectors.Vocab at 0x22dbfda8c50>,
#  'ironside': <gensim.models.keyedvectors.Vocab at 0x22dbed05710>,
#  'ewan': <gensim.models.keyedvectors.Vocab at 0x22dbeb72668>,
#  'wanders': <gensim.models.keyedvectors.Vocab at 0x22dbed65a20>,
#  'coarse': <gensim.models.keyedvectors.Vocab at 0x22dbea559b0>,
#  'audiard': <gensim.models.keyedvectors.Vocab at 0x22dbecc0550>,
#  'examined': <gensim.models.keyedvectors.Vocab at 0x22dbd720160>,
#  'situations': <gensim.models.keyedvectors.Vocab at 0x22dbed9cf98>,
#  'hailed': <gensim.models.keyedvectors.Vocab at 0x22dbfdb50b8>,
#  'clyde': <gensim.models.keyedvectors.Vocab at 0x22dbec7ba20>,
#  'beside': <gensim.models.keyedvectors.Vocab at 0x22dbed1c0b8>,
#  'kindness': <gensim.models.keyedvectors.Vocab at 0x22dbea59160>,
#  'suffer': <gensim.models.keyedvectors.Vocab at 0x22dbea5ffd0>,
#  'frances': <gensim.models.keyedvectors.Vocab at 0x22dbea39c88>,
#  'hanna': <gensim.models.keyedvectors.Vocab at 0x22dbec04f98>,
#  'wiser': <gensim.models.keyedvectors.Vocab at 0x22dbec09550>,
#  'toll': <gensim.models.keyedvectors.Vocab at 0x22dbea9ad30>,
#  'manipulative': <gensim.models.keyedvectors.Vocab at 0x22dbfdc3f98>,
#  'volume': <gensim.models.keyedvectors.Vocab at 0x22dbeaa7b38>,
#  'armies': <gensim.models.keyedvectors.Vocab at 0x22dbea7f710>,
#  'packaged': <gensim.models.keyedvectors.Vocab at 0x22dbeb44b70>,
#  'tt': <gensim.models.keyedvectors.Vocab at 0x22dbec1bac8>,
#  'richness': <gensim.models.keyedvectors.Vocab at 0x22dbeb64c18>,
#  'id': <gensim.models.keyedvectors.Vocab at 0x22dbeb56ba8>,
#  'listens': <gensim.models.keyedvectors.Vocab at 0x22dbed25f98>,
#  'bewilderment': <gensim.models.keyedvectors.Vocab at 0x22dbea273c8>,
#  'reservation': <gensim.models.keyedvectors.Vocab at 0x22dbec69630>,
#  'casual': <gensim.models.keyedvectors.Vocab at 0x22dbeba8550>,
#  'rotting': <gensim.models.keyedvectors.Vocab at 0x22dbebc44a8>,
#  'democracy': <gensim.models.keyedvectors.Vocab at 0x22dbec9b8d0>,
#  'lip': <gensim.models.keyedvectors.Vocab at 0x22dbeadffd0>,
#  'dyan': <gensim.models.keyedvectors.Vocab at 0x22dbeaf2400>,
#  'mythology': <gensim.models.keyedvectors.Vocab at 0x22dbec5bac8>,
#  'intensely': <gensim.models.keyedvectors.Vocab at 0x22dbed21c50>,
#  'unsatisfied': <gensim.models.keyedvectors.Vocab at 0x22dbecd7358>,
#  'counting': <gensim.models.keyedvectors.Vocab at 0x22dbd71be80>,
#  'scholars': <gensim.models.keyedvectors.Vocab at 0x22dbea30a58>,
#  'lovers': <gensim.models.keyedvectors.Vocab at 0x22dbed29668>,
#  'rivers': <gensim.models.keyedvectors.Vocab at 0x22dbec37400>,
#  'yeager': <gensim.models.keyedvectors.Vocab at 0x22dbeb6c7f0>,
#  'aimless': <gensim.models.keyedvectors.Vocab at 0x22dbeb60630>,
#  'discarded': <gensim.models.keyedvectors.Vocab at 0x22dbed17198>,
#  'aykroyd': <gensim.models.keyedvectors.Vocab at 0x22dbec859e8>,
#  'instinct': <gensim.models.keyedvectors.Vocab at 0x22dbeb2c0b8>,
#  'menace': <gensim.models.keyedvectors.Vocab at 0x22dbecf7208>,
#  'lightning': <gensim.models.keyedvectors.Vocab at 0x22dbfda8f98>,
#  'awfulness': <gensim.models.keyedvectors.Vocab at 0x22dbec5bf98>,
#  'centered': <gensim.models.keyedvectors.Vocab at 0x22dbebdac50>,
#  'aspects': <gensim.models.keyedvectors.Vocab at 0x22dbebc4780>,
#  'sickening': <gensim.models.keyedvectors.Vocab at 0x22dbfd951d0>,
#  'karloff': <gensim.models.keyedvectors.Vocab at 0x22dbeb2c4e0>,
# ...
#  'consumed': <gensim.models.keyedvectors.Vocab at 0x22dbebb22e8>,
#  'skewed': <gensim.models.keyedvectors.Vocab at 0x22dbecdb940>,
#  'campy': <gensim.models.keyedvectors.Vocab at 0x22dbebc43c8>,
#  'terrorized': <gensim.models.keyedvectors.Vocab at 0x22dbeb08400>,
#  'arises': <gensim.models.keyedvectors.Vocab at 0x22dbfdbac18>,
#  'chimps': <gensim.models.keyedvectors.Vocab at 0x22dbea35b00>,
#  'hanzo': <gensim.models.keyedvectors.Vocab at 0x22dbec29c88>,
#  'grow': <gensim.models.keyedvectors.Vocab at 0x22dbea63438>,
#  'resigned': <gensim.models.keyedvectors.Vocab at 0x22dbec7b128>,
#  'mel': <gensim.models.keyedvectors.Vocab at 0x22dbec5b278>,
#  'stalwart': <gensim.models.keyedvectors.Vocab at 0x22dbeabf320>,
#  'families': <gensim.models.keyedvectors.Vocab at 0x22dbeaa35c0>,
#  'episodes': <gensim.models.keyedvectors.Vocab at 0x22dbfdbacf8>,
#  'blindly': <gensim.models.keyedvectors.Vocab at 0x22dbed8eb00>,
#  'paths': <gensim.models.keyedvectors.Vocab at 0x22dbed73390>,
#  'rehab': <gensim.models.keyedvectors.Vocab at 0x22dbea39048>,
#  'illegal': <gensim.models.keyedvectors.Vocab at 0x22dbead6160>,
#  'politician': <gensim.models.keyedvectors.Vocab at 0x22dbebd6c50>,
#  'kurosawa': <gensim.models.keyedvectors.Vocab at 0x22dbeca5278>,
#  'hides': <gensim.models.keyedvectors.Vocab at 0x22dbeccd358>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x22dbea6c860>,
#  'singleton': <gensim.models.keyedvectors.Vocab at 0x22dbed5cbe0>,
#  'nickname': <gensim.models.keyedvectors.Vocab at 0x22dbec44588>,
#  'protagonists': <gensim.models.keyedvectors.Vocab at 0x22dbfd917b8>,
#  'horsemen': <gensim.models.keyedvectors.Vocab at 0x22dbeababa8>,
#  'fourth': <gensim.models.keyedvectors.Vocab at 0x22dbd7202b0>,
#  'outright': <gensim.models.keyedvectors.Vocab at 0x22dbed97668>,
#  'portraying': <gensim.models.keyedvectors.Vocab at 0x22dbed09828>,
#  'arms': <gensim.models.keyedvectors.Vocab at 0x22dbeb16d68>,
#  'gabby': <gensim.models.keyedvectors.Vocab at 0x22dbeb76d68>,
#  'crippled': <gensim.models.keyedvectors.Vocab at 0x22dbfdd5748>,
#  'chaotic': <gensim.models.keyedvectors.Vocab at 0x22dbeb56f60>,
#  'scotty': <gensim.models.keyedvectors.Vocab at 0x22dbed45e48>,
#  'pizza': <gensim.models.keyedvectors.Vocab at 0x22dbec97e80>,
#  'theorists': <gensim.models.keyedvectors.Vocab at 0x22dbea306a0>,
#  'genre': <gensim.models.keyedvectors.Vocab at 0x22dbea306d8>,
#  'aggravating': <gensim.models.keyedvectors.Vocab at 0x22dbec4d1d0>,
#  'blasphemy': <gensim.models.keyedvectors.Vocab at 0x22dbecfbd68>,
#  'opponent': <gensim.models.keyedvectors.Vocab at 0x22dbec12e48>,
#  'villainy': <gensim.models.keyedvectors.Vocab at 0x22dbeab16a0>,
#  'coincidences': <gensim.models.keyedvectors.Vocab at 0x22dbeb9acf8>,
#  'dwight': <gensim.models.keyedvectors.Vocab at 0x22dbed4e940>,
#  'em': <gensim.models.keyedvectors.Vocab at 0x22dbebb2518>,
#  'milton': <gensim.models.keyedvectors.Vocab at 0x22dbd70e438>,
#  'aesthetics': <gensim.models.keyedvectors.Vocab at 0x22dbfdb16a0>,
#  'philippe': <gensim.models.keyedvectors.Vocab at 0x22dbea95f60>,
#  'spitting': <gensim.models.keyedvectors.Vocab at 0x22dbebd2320>,
#  'pound': <gensim.models.keyedvectors.Vocab at 0x22dbed532b0>,
#  'phenomenal': <gensim.models.keyedvectors.Vocab at 0x22dbed01588>,
#  'domination': <gensim.models.keyedvectors.Vocab at 0x22dbec97780>,
#  'tormented': <gensim.models.keyedvectors.Vocab at 0x22dbd729f98>,
#  'engages': <gensim.models.keyedvectors.Vocab at 0x22dbed575c0>,
#  'vi': <gensim.models.keyedvectors.Vocab at 0x22dbea75860>,
#  'orgasm': <gensim.models.keyedvectors.Vocab at 0x22dbebba358>,
#  'lingers': <gensim.models.keyedvectors.Vocab at 0x22dbea47cc0>,
#  'braveheart': <gensim.models.keyedvectors.Vocab at 0x22dbeba05c0>,
#  'potty': <gensim.models.keyedvectors.Vocab at 0x22dbebb6390>,
#  'spiritually': <gensim.models.keyedvectors.Vocab at 0x22dbed5c668>,
#  'amrita': <gensim.models.keyedvectors.Vocab at 0x22dbfdd9be0>,
#  'yearn': <gensim.models.keyedvectors.Vocab at 0x22dbfd7e320>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x22dbebf2cf8>,
#  'emil': <gensim.models.keyedvectors.Vocab at 0x22dbeb248d0>,
#  'parasite': <gensim.models.keyedvectors.Vocab at 0x22dbea630b8>,
#  'essential': <gensim.models.keyedvectors.Vocab at 0x22dbec69588>,
#  'slugs': <gensim.models.keyedvectors.Vocab at 0x22dbfdac320>,
#  'environment': <gensim.models.keyedvectors.Vocab at 0x22dbeba4a20>,
#  'evoke': <gensim.models.keyedvectors.Vocab at 0x22dbfd88400>,
#  'noir': <gensim.models.keyedvectors.Vocab at 0x22dbeb3aac8>,
#  'priest': <gensim.models.keyedvectors.Vocab at 0x22dbeb64240>,
#  'quasi': <gensim.models.keyedvectors.Vocab at 0x22dbd709cc0>,
#  'alphabet': <gensim.models.keyedvectors.Vocab at 0x22dbd720d30>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x22dbebba4a8>,
#  'approaching': <gensim.models.keyedvectors.Vocab at 0x22dbeb08320>,
#  'repeatedly': <gensim.models.keyedvectors.Vocab at 0x22dbec72978>,
#  'harmon': <gensim.models.keyedvectors.Vocab at 0x22dbebedc50>,
#  'review': <gensim.models.keyedvectors.Vocab at 0x22dbed9c0f0>,
#  'voorhees': <gensim.models.keyedvectors.Vocab at 0x22dbed2e2b0>,
#  'relying': <gensim.models.keyedvectors.Vocab at 0x22dbed17828>,
#  'unconvincingly': <gensim.models.keyedvectors.Vocab at 0x22dbeb2cc50>,
#  'politicians': <gensim.models.keyedvectors.Vocab at 0x22dbebe07b8>,
#  'grimy': <gensim.models.keyedvectors.Vocab at 0x22dbfd8cd68>,
#  'beach': <gensim.models.keyedvectors.Vocab at 0x22dbeabfd68>,
#  'keanu': <gensim.models.keyedvectors.Vocab at 0x22dbeb32da0>,
#  'liam': <gensim.models.keyedvectors.Vocab at 0x22dbec401d0>,
#  'babylon': <gensim.models.keyedvectors.Vocab at 0x22dbebb65c0>,
#  'theirs': <gensim.models.keyedvectors.Vocab at 0x22dbebfb2e8>,
#  'shalhoub': <gensim.models.keyedvectors.Vocab at 0x22dbeaec630>,
#  'status': <gensim.models.keyedvectors.Vocab at 0x22dbfdb59e8>,
#  'hates': <gensim.models.keyedvectors.Vocab at 0x22dbed172b0>,
#  'visited': <gensim.models.keyedvectors.Vocab at 0x22dbfdd2a58>,
#  'bats': <gensim.models.keyedvectors.Vocab at 0x22dbeb36f98>,
#  'brook': <gensim.models.keyedvectors.Vocab at 0x22dbeb363c8>,
#  'generating': <gensim.models.keyedvectors.Vocab at 0x22dbeb043c8>,
#  'yelled': <gensim.models.keyedvectors.Vocab at 0x22dbed93780>,
#  'sits': <gensim.models.keyedvectors.Vocab at 0x22dbecd7e80>,
#  'gage': <gensim.models.keyedvectors.Vocab at 0x22dbd725a90>,
#  'centre': <gensim.models.keyedvectors.Vocab at 0x22dbeca0c18>,
#  'feelings': <gensim.models.keyedvectors.Vocab at 0x22dbec24160>,
#  'relive': <gensim.models.keyedvectors.Vocab at 0x22dbeb64080>,
#  'hartley': <gensim.models.keyedvectors.Vocab at 0x22dbed37780>,
#  'moon': <gensim.models.keyedvectors.Vocab at 0x22dbeb562e8>,
#  'vivek': <gensim.models.keyedvectors.Vocab at 0x22dbebe8c88>,
#  'din': <gensim.models.keyedvectors.Vocab at 0x22dbeca9748>,
#  'nam': <gensim.models.keyedvectors.Vocab at 0x22dbeb047f0>,
#  'individual': <gensim.models.keyedvectors.Vocab at 0x22dbea87550>,
#  'slip': <gensim.models.keyedvectors.Vocab at 0x22dbea6c208>,
#  'throat': <gensim.models.keyedvectors.Vocab at 0x22dbecdb668>,
#  'subjected': <gensim.models.keyedvectors.Vocab at 0x22dbfdcd198>,
#  'concocted': <gensim.models.keyedvectors.Vocab at 0x22dbeacc780>,
#  'mack': <gensim.models.keyedvectors.Vocab at 0x22dbea67208>,
#  'onwards': <gensim.models.keyedvectors.Vocab at 0x22dbeb72978>,
#  'mirren': <gensim.models.keyedvectors.Vocab at 0x22dbfdbeb38>,
#  'appetite': <gensim.models.keyedvectors.Vocab at 0x22dbeaecc18>,
#  'clearly': <gensim.models.keyedvectors.Vocab at 0x22dbeceeda0>,
#  'paid': <gensim.models.keyedvectors.Vocab at 0x22dbec12400>,
#  'abraham': <gensim.models.keyedvectors.Vocab at 0x22dbed45550>,
#  'thereof': <gensim.models.keyedvectors.Vocab at 0x22dbfda8be0>,
#  'wreak': <gensim.models.keyedvectors.Vocab at 0x22dbebed780>,
#  'blasts': <gensim.models.keyedvectors.Vocab at 0x22dbea75ac8>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x22dbec57278>,
#  'mani': <gensim.models.keyedvectors.Vocab at 0x22dbeb80c50>,
#  'weave': <gensim.models.keyedvectors.Vocab at 0x22dbec64fd0>,
#  'calm': <gensim.models.keyedvectors.Vocab at 0x22dbed1c2b0>,
#  'bram': <gensim.models.keyedvectors.Vocab at 0x22dbed01710>,
#  'satisfy': <gensim.models.keyedvectors.Vocab at 0x22dbecc97f0>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x22dbeab1da0>,
#  'toughest': <gensim.models.keyedvectors.Vocab at 0x22dbed69898>,
#  'videos': <gensim.models.keyedvectors.Vocab at 0x22dbec40b00>,
#  'immortal': <gensim.models.keyedvectors.Vocab at 0x22dbead19e8>,
#  'bickering': <gensim.models.keyedvectors.Vocab at 0x22dbeba0080>,
#  'yummy': <gensim.models.keyedvectors.Vocab at 0x22dbed49780>,
#  'haggard': <gensim.models.keyedvectors.Vocab at 0x22dbeaa7ac8>,
#  'february': <gensim.models.keyedvectors.Vocab at 0x22dbeb96ef0>,
#  'titillating': <gensim.models.keyedvectors.Vocab at 0x22dbed414e0>,
#  'charlton': <gensim.models.keyedvectors.Vocab at 0x22dbed01c18>,
#  'pictured': <gensim.models.keyedvectors.Vocab at 0x22dbeaffcf8>,
#  'delivering': <gensim.models.keyedvectors.Vocab at 0x22dbec6d550>,
#  'register': <gensim.models.keyedvectors.Vocab at 0x22dbecdb7f0>,
#  'sword': <gensim.models.keyedvectors.Vocab at 0x22dbed17f28>,
#  'limbs': <gensim.models.keyedvectors.Vocab at 0x22dbeca9b38>,
#  'doorstep': <gensim.models.keyedvectors.Vocab at 0x22dbeae8b38>,
#  'raises': <gensim.models.keyedvectors.Vocab at 0x22dbed6ea90>,
#  'submarine': <gensim.models.keyedvectors.Vocab at 0x22dbeba8828>,
#  'repressed': <gensim.models.keyedvectors.Vocab at 0x22dbebf22b0>,
#  'marshal': <gensim.models.keyedvectors.Vocab at 0x22dbea877b8>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x22dbfd88d68>,
#  'gentle': <gensim.models.keyedvectors.Vocab at 0x22dbec9b1d0>,
#  'praises': <gensim.models.keyedvectors.Vocab at 0x22dbeb3aa20>,
#  'tears': <gensim.models.keyedvectors.Vocab at 0x22dbec60a90>,
#  'dumpster': <gensim.models.keyedvectors.Vocab at 0x22dbebed160>,
#  'identification': <gensim.models.keyedvectors.Vocab at 0x22dbec16da0>,
#  'gere': <gensim.models.keyedvectors.Vocab at 0x22dbebdabe0>,
#  'swordplay': <gensim.models.keyedvectors.Vocab at 0x22dbeb1aa58>,
#  'hulk': <gensim.models.keyedvectors.Vocab at 0x22dbeb889b0>,
#  'defeat': <gensim.models.keyedvectors.Vocab at 0x22dbfd9e780>,
#  'conduct': <gensim.models.keyedvectors.Vocab at 0x22dbebc8a58>,
#  'peaks': <gensim.models.keyedvectors.Vocab at 0x22dbeba8940>,
#  'librarian': <gensim.models.keyedvectors.Vocab at 0x22dbec0da20>,
#  'deluise': <gensim.models.keyedvectors.Vocab at 0x22dbea27550>,
#  'poignant': <gensim.models.keyedvectors.Vocab at 0x22dbeb76898>,
#  'dracula': <gensim.models.keyedvectors.Vocab at 0x22dbeaba2e8>,
#  'represent': <gensim.models.keyedvectors.Vocab at 0x22dbec4d390>,
#  'seemed': <gensim.models.keyedvectors.Vocab at 0x22dbeb92198>,
#  'steam': <gensim.models.keyedvectors.Vocab at 0x22dbeb08898>,
#  'par': <gensim.models.keyedvectors.Vocab at 0x22dbea55a20>,
#  'disgusted': <gensim.models.keyedvectors.Vocab at 0x22dbeb7af98>,
#  'lonely': <gensim.models.keyedvectors.Vocab at 0x22dbebba208>,
#  'snoopy': <gensim.models.keyedvectors.Vocab at 0x22dbfd7a588>,
#  'scathing': <gensim.models.keyedvectors.Vocab at 0x22dbec37780>,
#  'lately': <gensim.models.keyedvectors.Vocab at 0x22dbed1c5f8>,
#  'scary': <gensim.models.keyedvectors.Vocab at 0x22dbfdc8198>,
#  'warners': <gensim.models.keyedvectors.Vocab at 0x22dbeab5cc0>,
#  'poorest': <gensim.models.keyedvectors.Vocab at 0x22dbed33320>,
#  'besson': <gensim.models.keyedvectors.Vocab at 0x22dbea9a2e8>,
#  'celebrities': <gensim.models.keyedvectors.Vocab at 0x22dbed29080>,
#  'cruelty': <gensim.models.keyedvectors.Vocab at 0x22dbea9f940>,
#  'pork': <gensim.models.keyedvectors.Vocab at 0x22dbeabf1d0>,
#  'rhapsody': <gensim.models.keyedvectors.Vocab at 0x22dbeb76748>,
#  'vivian': <gensim.models.keyedvectors.Vocab at 0x22dbed77c50>,
#  'doc': <gensim.models.keyedvectors.Vocab at 0x22dbeabf978>,
#  'hagen': <gensim.models.keyedvectors.Vocab at 0x22dbed9c710>,
#  'logo': <gensim.models.keyedvectors.Vocab at 0x22dbeb04a20>,
#  'yee': <gensim.models.keyedvectors.Vocab at 0x22dbec20fd0>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x22dbea2b5f8>,
#  'dumbed': <gensim.models.keyedvectors.Vocab at 0x22dbec85e10>,
#  'heh': <gensim.models.keyedvectors.Vocab at 0x22dbecc9b00>,
#  'fit': <gensim.models.keyedvectors.Vocab at 0x22dbea30c50>,
#  'melts': <gensim.models.keyedvectors.Vocab at 0x22dbecf7630>,
#  'anita': <gensim.models.keyedvectors.Vocab at 0x22dbed77dd8>,
#  'idiocy': <gensim.models.keyedvectors.Vocab at 0x22dbecfbda0>,
#  'wrapped': <gensim.models.keyedvectors.Vocab at 0x22dbeac84e0>,
#  'rips': <gensim.models.keyedvectors.Vocab at 0x22dbeb6c198>,
#  'lumet': <gensim.models.keyedvectors.Vocab at 0x22dbea6c358>,
#  'unforgivable': <gensim.models.keyedvectors.Vocab at 0x22dbeaf6630>,
#  'stranger': <gensim.models.keyedvectors.Vocab at 0x22dbea5f0f0>,
#  'serbia': <gensim.models.keyedvectors.Vocab at 0x22dbea83da0>,
#  'ancient': <gensim.models.keyedvectors.Vocab at 0x22dbebe07f0>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x22dbd71b978>,
#  'rodgers': <gensim.models.keyedvectors.Vocab at 0x22dbebc4748>,
#  'bennett': <gensim.models.keyedvectors.Vocab at 0x22dbec16c50>,
#  'excalibur': <gensim.models.keyedvectors.Vocab at 0x22dbed05978>,
#  'attributed': <gensim.models.keyedvectors.Vocab at 0x22dbfd95cc0>,
#  'shades': <gensim.models.keyedvectors.Vocab at 0x22dbeb48080>,
#  'daytime': <gensim.models.keyedvectors.Vocab at 0x22dbeae48d0>,
#  'casey': <gensim.models.keyedvectors.Vocab at 0x22dbead15f8>,
#  'rand': <gensim.models.keyedvectors.Vocab at 0x22dbea3e0f0>,
#  'worn': <gensim.models.keyedvectors.Vocab at 0x22dbeb60438>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x22dbea43160>,
#  'scarce': <gensim.models.keyedvectors.Vocab at 0x22dbec12a90>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x22dbecc50f0>,
#  'ought': <gensim.models.keyedvectors.Vocab at 0x22dbd71b550>,
#  'angelo': <gensim.models.keyedvectors.Vocab at 0x22dbec00b70>,
#  'patients': <gensim.models.keyedvectors.Vocab at 0x22dbea8cc18>,
#  'ridiculed': <gensim.models.keyedvectors.Vocab at 0x22dbebc8c18>,
#  'parrot': <gensim.models.keyedvectors.Vocab at 0x22dbebb2c18>,
#  'coup': <gensim.models.keyedvectors.Vocab at 0x22dbed056a0>,
#  'texture': <gensim.models.keyedvectors.Vocab at 0x22dbed05c88>,
#  'proceeds': <gensim.models.keyedvectors.Vocab at 0x22dbece5438>,
#  'poland': <gensim.models.keyedvectors.Vocab at 0x22dbecd30b8>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x22dbea63588>,
#  'viable': <gensim.models.keyedvectors.Vocab at 0x22dbebba5c0>,
#  'evoked': <gensim.models.keyedvectors.Vocab at 0x22dbfdbeac8>,
#  'influential': <gensim.models.keyedvectors.Vocab at 0x22dbeab5860>,
#  'sets': <gensim.models.keyedvectors.Vocab at 0x22dbec7b940>,
#  'chat': <gensim.models.keyedvectors.Vocab at 0x22dbecad550>,
#  'millionaire': <gensim.models.keyedvectors.Vocab at 0x22dbea8c4e0>,
#  'farm': <gensim.models.keyedvectors.Vocab at 0x22dbeab5b70>,
#  'busy': <gensim.models.keyedvectors.Vocab at 0x22dbfdd5940>,
#  'eleniak': <gensim.models.keyedvectors.Vocab at 0x22dbebc0cc0>,
#  'swell': <gensim.models.keyedvectors.Vocab at 0x22dbecc5518>,
#  'gamera': <gensim.models.keyedvectors.Vocab at 0x22dbed85c88>,
#  'coach': <gensim.models.keyedvectors.Vocab at 0x22dbea95eb8>,
#  'lays': <gensim.models.keyedvectors.Vocab at 0x22dbec7b160>,
#  'freak': <gensim.models.keyedvectors.Vocab at 0x22dbeb602b0>,
#  'existent': <gensim.models.keyedvectors.Vocab at 0x22dbeb567b8>,
#  'whale': <gensim.models.keyedvectors.Vocab at 0x22dbeb8c438>,
#  'brosnan': <gensim.models.keyedvectors.Vocab at 0x22dbeb40ac8>,
#  'porno': <gensim.models.keyedvectors.Vocab at 0x22dbfda3048>,
#  'franz': <gensim.models.keyedvectors.Vocab at 0x22dbea9f9e8>,
#  'growing': <gensim.models.keyedvectors.Vocab at 0x22dbfdc3080>,
#  'didnt': <gensim.models.keyedvectors.Vocab at 0x22dbeba0198>,
#  'golf': <gensim.models.keyedvectors.Vocab at 0x22dbfdb53c8>,
#  'ongoing': <gensim.models.keyedvectors.Vocab at 0x22dbebad8d0>,
#  'ladder': <gensim.models.keyedvectors.Vocab at 0x22dbec85358>,
#  'hellgate': <gensim.models.keyedvectors.Vocab at 0x22dbfdb15f8>,
#  'bebop': <gensim.models.keyedvectors.Vocab at 0x22dbeaf2cf8>,
#  'analogy': <gensim.models.keyedvectors.Vocab at 0x22dbecb3cf8>,
#  ...}

# %%
# print an example word vector
print(type(model.wv['flower']), model.wv['flower'].shape, model.wv['flower'])
# Out:
# <class 'numpy.ndarray'> (300,) [-0.10062144 -0.0373067  -0.01177098  0.01897836 -0.0582221   0.01059407
#  -0.01903199 -0.03965223  0.01402162  0.06537773 -0.00234694  0.04390201
#  -0.05563514 -0.08568203  0.0407625  -0.04255536  0.01772894 -0.1099337
#  -0.07264499 -0.00234345  0.03807487 -0.00944625 -0.05043571  0.04681217
#  -0.00365645 -0.0103762   0.04115774  0.00555492 -0.10632971  0.0169404
#  -0.11786894  0.04571186 -0.05091904  0.02057571  0.03425485  0.03920021
#  -0.04902321  0.00347328 -0.00153042 -0.01283417 -0.03548294  0.0088976
#  -0.07267819  0.06515966  0.04340233  0.09843781  0.10642156 -0.05319658
#  -0.00077657 -0.05363375 -0.0399363  -0.06495567 -0.00632878  0.05095981
#  -0.06730764  0.09523525 -0.02798701  0.07545108  0.01979266  0.04176433
#   0.1159274   0.00106818 -0.03873147  0.04909463 -0.01007216  0.00981472
#   0.02324556 -0.0216225  -0.09122876  0.07475305  0.03391683  0.10518024
#   0.03046319 -0.04791102 -0.01907292 -0.01433413  0.07916567  0.09057612
#   0.00386166  0.09806953 -0.07019988  0.09894915 -0.14683856  0.00835612
#  -0.03176533  0.00162643 -0.11936495  0.1633441   0.08095063  0.00738192
#  -0.03914373 -0.0104431  -0.07455496  0.03287641 -0.11903953  0.06424571
#  -0.03383875  0.08561545  0.02677215  0.06943733 -0.03290206  0.03024592
#  -0.01470755  0.0229104   0.02176668  0.03129123  0.04292469 -0.022803
#  -0.1379928  -0.05876822  0.0435728   0.00897754 -0.00330008  0.00609306
#  -0.12001521 -0.02907595 -0.05635565 -0.0808863  -0.03349741 -0.02219571
#   0.08014278 -0.0125114  -0.02068494 -0.10029133 -0.01042783  0.01869418
#  -0.06742865  0.00485548 -0.00028406 -0.00452106 -0.00236728 -0.06807517
#  -0.04630466 -0.0068929  -0.00184073 -0.05778326  0.08856297  0.02505678
#  -0.03306761  0.10608204 -0.04863417  0.06211456 -0.05755682  0.0486347
#   0.01435408  0.0220487  -0.05004469 -0.01315897 -0.01252421 -0.06019149
#  -0.04200643 -0.12999696  0.06418345  0.02044413 -0.03474237 -0.0521601
#  -0.00608073  0.01350062 -0.04928019 -0.08896437 -0.00032458  0.03417931
#   0.08436456  0.02615268  0.03243193 -0.04142191  0.00778394  0.01069357
#  -0.04326699 -0.04834916  0.04288387 -0.00068805  0.01202427 -0.04830556
#  -0.01772442 -0.03256912 -0.09396352  0.02044688 -0.01520567 -0.07808261
#  -0.06294115 -0.00639285  0.00396094 -0.04144744 -0.01185095 -0.04030229
#  -0.11179148 -0.04437778 -0.02732705 -0.17891836  0.0777493   0.14118414
#   0.05599936  0.12491927 -0.05391357 -0.06195787 -0.06251658 -0.05971323
#   0.05532656  0.05430823  0.01005826 -0.06182532 -0.01629707  0.06407042
#  -0.05672171 -0.0452879  -0.01384821  0.02704946 -0.00183812 -0.01971617
#   0.03854487 -0.0846166   0.01789048  0.04083176  0.00994893  0.02757046
#   0.03929146  0.02330115 -0.05736932  0.08833025  0.08766758  0.0248668
#   0.08107211  0.0788011   0.00916414 -0.01414591  0.11350945 -0.04448659
#   0.01812488  0.04716337  0.01802003 -0.02431151 -0.03169637  0.00066945
#  -0.11437269 -0.04534143 -0.01038094 -0.07953521  0.02495375  0.07258079
#   0.0589174  -0.02718468  0.02144874  0.01525518 -0.04531312  0.06809862
#   0.02562868  0.00902367  0.06743129  0.00626931 -0.0895497  -0.03835214
#   0.04185072  0.01618658  0.0418125  -0.06580179 -0.05475337 -0.05973982
#   0.0445207  -0.00260627 -0.06415676 -0.10341018  0.04573037  0.12574463
#  -0.04151743  0.03677652 -0.06560897  0.07373887 -0.01680187  0.06888911
#  -0.00507357 -0.00798682  0.11068232 -0.0671474   0.00702557  0.01612346
#   0.10250172 -0.05867817  0.05836616 -0.01916911 -0.06510103 -0.05944504
#   0.14685425  0.08476228  0.03214929  0.01449912 -0.00151494 -0.00595391
#   0.00482348 -0.08570328 -0.01734602  0.04135181  0.00400573  0.06585564
#   0.04443138 -0.07126606  0.09369382  0.06429838 -0.00565587  0.00478941]

# %%
# Create a Word / Index dictionary, mapping each vocabulary word to
# a cluster number
word_centroid_map = dict(zip(model.wv.index2word, idx))

# %%
# Print the first ten clusters
for cluster in range(0, 10):
    #
    # Print the cluster number
    print("\nCluster %d" % cluster)
    #
    # Find all of the words for that cluster number, and print them out
    words = []
    for i in range(0, len(word_centroid_map.values())):
        if list(word_centroid_map.values())[i] == cluster:
            words.append(list(word_centroid_map.keys())[i])
    print(words)
# Out:
# Cluster 0
# ['vertigo', 'alfred']
#
# Cluster 1
# ['wounds', 'injuries']
#
# Cluster 2
# ['jordan', 'dicaprio']
#
# Cluster 3
# ['minorities', 'ethnic', 'traditionally', 'asians', 'intellectuals', 'regional']
#
# Cluster 4
# ['scattered', 'sprinkled', 'interludes', 'inter', 'montages']
#
# Cluster 5
# ['suit', 'wig', 'outfit', 'uniform', 'costume']
#
# Cluster 6
# ['parrot', 'blind', 'mute', 'transvestite', 'deaf']
#
# Cluster 7
# ['fix']
#
# Cluster 8
# ['constant', 'nastiness', 'uncontrollable', 'outbursts', 'nausea']
#
# Cluster 9
# ['seaside']

# %%
# Read data from files
train = pd.read_csv('./labeledTrainData.tsv', header=0, delimiter='\t', quoting=3)
test = pd.read_csv('./testData.tsv', header=0, delimiter='\t', quoting=3)

# %%
print("Cleaning training reviews")
clean_train_reviews = []
for review in train['review']:
    clean_train_reviews.append(KaggleWord2VecUtility.review_to_wordlist(review, \
                                remove_stopwords=True))

print("Cleaning test reviews")
clean_test_reviews = []
for review in test['review']:
    clean_test_reviews.append(KaggleWord2VecUtility.review_to_wordlist(review, \
                                remove_stopwords = True))
    
# ****** Create bags of centroids
#
# Pre-allocate an array for the training set bags of centroids (for speed)
train_centroids = np.zeros((train['review'].size, num_clusters), \
                          dtype='float32')

# Transform the training set reviews into bags of centroids
counter = 0
for review in clean_train_reviews:
    train_centroids[counter] = create_bag_of_centroids(review, \
        word_centroid_map)
    counter += 1
    
# Repeat for test reviews
test_centroids = np.zeros((test['review'].size, num_clusters), \
                         dtype = 'float32')

counter = 0
for review in clean_test_reviews:
    test_centroids[counter] = create_bag_of_centroids(review, \
        word_centroid_map)
    counter += 1
    
# ****** Fit a random forest and extract predictions
#
forest = RandomForestClassifier(n_estimators = 100)

# Fitting the forest may take a few minutes
print("Fitting a random forest to labeled training data...")
forest = forest.fit(train_centroids, train['sentiment'])
result = forest.predict(test_centroids)

# Write the test results
output = pd.DataFrame(data={'id': test['id'], 'sentiment': result})
output.to_csv('BagOfCentroids.csv', index=False, quoting=3)
print("Wrote BagOfCentroids.csv")
# Out:
# Cleaning training reviews
# C:\Dev\Anaconda3\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Cleaning test reviews
# Fitting a random forest to labeled training data...
# Wrote BagOfCentroids.csv
